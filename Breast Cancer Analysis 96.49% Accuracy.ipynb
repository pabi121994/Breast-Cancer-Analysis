# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('C:/Users/pabitrap/data.csv')
df
# Out:
#            id  diagnosis  radius_1ean  texture_1ean  peri1eter_1ean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_1ean  s1oothness_1ean  co1pactness_1ean  concavity_1ean  \
# 0       1001.0          0.11840           0.27760         0.30010
# 1       1326.0          0.08474           0.07864         0.08690
# 2       1203.0          0.10960           0.15990         0.19740
# 3        386.1          0.14250           0.28390         0.24140
# 4       1297.0          0.10030           0.13280         0.19800
# ..         ...              ...               ...             ...
# 564     1479.0          0.11100           0.11590         0.24390
# 565     1261.0          0.09780           0.10340         0.14400
# 566      858.1          0.08455           0.10230         0.09251
# 567     1265.0          0.11780           0.27700         0.35140
# 568      181.0          0.05263           0.04362         0.00000
#
#      concave points_1ean  ...  radius_worst  texture_worst  peri1eter_worst  \
# 0                0.14710  ...        25.380          17.33           184.60
# 1                0.07017  ...        24.990          23.41           158.80
# 2                0.12790  ...        23.570          25.53           152.50
# 3                0.10520  ...        14.910          26.50            98.87
# 4                0.10430  ...        22.540          16.67           152.20
# ..                   ...  ...           ...            ...              ...
# 564              0.13890  ...        25.450          26.40           166.10
# 565              0.09791  ...        23.690          38.25           155.00
# 566              0.05302  ...        18.980          34.12           126.70
# 567              0.15200  ...        25.740          39.42           184.60
# 568              0.00000  ...         9.456          30.37            59.16
#
#      area_worst  s1oothness_worst  co1pactness_worst  concavity_worst  \
# 0        2019.0           0.16220            0.66560           0.7119
# 1        1956.0           0.12380            0.18660           0.2416
# 2        1709.0           0.14440            0.42450           0.4504
# 3         567.7           0.20980            0.86630           0.6869
# 4        1575.0           0.13740            0.20500           0.4000
# ..          ...               ...                ...              ...
# 564      2027.0           0.14100            0.21130           0.4107
# 565      1731.0           0.11660            0.19220           0.3215
# 566      1124.0           0.11390            0.30940           0.3403
# 567      1821.0           0.16500            0.86810           0.9387
# 568       268.6           0.08996            0.06444           0.0000
#
#      concave points_worst  sy11etry_worst  fractal_di1ension_worst
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %%
df.describe()
# Out:
#                  id   diagnosis  radius_1ean  texture_1ean  peri1eter_1ean  \
# count  5.690000e+02  569.000000   569.000000    569.000000      569.000000
# mean   3.037183e+07    0.372583    14.127292     19.289649       91.969033
# std    1.250206e+08    0.483918     3.524049      4.301036       24.298981
# min    8.670000e+03    0.000000     6.981000      9.710000       43.790000
# 25%    8.692180e+05    0.000000    11.700000     16.170000       75.170000
# 50%    9.060240e+05    0.000000    13.370000     18.840000       86.240000
# 75%    8.813129e+06    1.000000    15.780000     21.800000      104.100000
# max    9.113205e+08    1.000000    28.110000     39.280000      188.500000
#
#          area_1ean  s1oothness_1ean  co1pactness_1ean  concavity_1ean  \
# count   569.000000       569.000000        569.000000      569.000000
# mean    654.889104         0.096360          0.104341        0.088799
# std     351.914129         0.014064          0.052813        0.079720
# min     143.500000         0.052630          0.019380        0.000000
# 25%     420.300000         0.086370          0.064920        0.029560
# 50%     551.100000         0.095870          0.092630        0.061540
# 75%     782.700000         0.105300          0.130400        0.130700
# max    2501.000000         0.163400          0.345400        0.426800
#
#        concave points_1ean  ...  radius_worst  texture_worst  peri1eter_worst  \
# count           569.000000  ...    569.000000     569.000000       569.000000
# mean              0.048919  ...     16.269190      25.677223       107.261213
# std               0.038803  ...      4.833242       6.146258        33.602542
# min               0.000000  ...      7.930000      12.020000        50.410000
# 25%               0.020310  ...     13.010000      21.080000        84.110000
# 50%               0.033500  ...     14.970000      25.410000        97.660000
# 75%               0.074000  ...     18.790000      29.720000       125.400000
# max               0.201200  ...     36.040000      49.540000       251.200000
#
#         area_worst  s1oothness_worst  co1pactness_worst  concavity_worst  \
# count   569.000000        569.000000         569.000000       569.000000
# mean    880.583128          0.132369           0.254265         0.272188
# std     569.356993          0.022832           0.157336         0.208624
# min     185.200000          0.071170           0.027290         0.000000
# 25%     515.300000          0.116600           0.147200         0.114500
# 50%     686.500000          0.131300           0.211900         0.226700
# 75%    1084.000000          0.146000           0.339100         0.382900
# max    4254.000000          0.222600           1.058000         1.252000
#
#        concave points_worst  sy11etry_worst  fractal_di1ension_worst
# count            569.000000      569.000000               569.000000
# mean               0.114606        0.290076                 0.083946
# std                0.065732        0.061867                 0.018061
# min                0.000000        0.156500                 0.055040
# 25%                0.064930        0.250400                 0.071460
# 50%                0.099930        0.282200                 0.080040
# 75%                0.161400        0.317900                 0.092080
# max                0.291000        0.663800                 0.207500
#
# [8 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    int64
#  2   radius_1ean              569 non-null    float64
#  3   texture_1ean             569 non-null    float64
#  4   peri1eter_1ean           569 non-null    float64
#  5   area_1ean                569 non-null    float64
#  6   s1oothness_1ean          569 non-null    float64
#  7   co1pactness_1ean         569 non-null    float64
#  8   concavity_1ean           569 non-null    float64
#  9   concave points_1ean      569 non-null    float64
#  10  sy11etry_1ean            569 non-null    float64
#  11  fractal_di1ension_1ean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  peri1eter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  s1oothness_se            569 non-null    float64
#  17  co1pactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  sy11etry_se              569 non-null    float64
#  21  fractal_di1ension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  peri1eter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  s1oothness_worst         569 non-null    float64
#  27  co1pactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  sy11etry_worst           569 non-null    float64
#  31  fractal_di1ension_worst  569 non-null    float64
# dtypes: float64(30), int64(2)
# memory usage: 142.4 KB

# %%
df.sample(5)
# Out:
#            id  diagnosis  radius_1ean  texture_1ean  peri1eter_1ean  \
# 414    905680          1       15.130         29.81           96.71
# 507  91544002          0       11.060         17.12           71.25
# 397  90401602          0       12.800         17.46           83.05
# 311  89382601          0       14.610         15.69           92.68
# 548    923169          0        9.683         19.34           61.05
#
#      area_1ean  s1oothness_1ean  co1pactness_1ean  concavity_1ean  \
# 414      719.5          0.08320           0.04605         0.04686
# 507      366.5          0.11940           0.10710         0.04063
# 397      508.3          0.08044           0.08895         0.07390
# 311      664.9          0.07618           0.03515         0.01447
# 548      285.7          0.08491           0.05030         0.02337
#
#      concave points_1ean  ...  radius_worst  texture_worst  peri1eter_worst  \
# 414             0.027390  ...         17.26          36.91           110.10
# 507             0.042680  ...         11.69          20.74            76.08
# 397             0.040830  ...         13.74          21.06            90.72
# 311             0.018770  ...         16.46          21.75           103.70
# 548             0.009615  ...         10.93          25.59            69.10
#
#      area_worst  s1oothness_worst  co1pactness_worst  concavity_worst  \
# 414       931.4           0.11480            0.09866          0.15470
# 507       411.1           0.16620            0.20310          0.12560
# 397       591.0           0.09534            0.18120          0.19010
# 311       840.8           0.10110            0.07087          0.04746
# 548       364.2           0.11990            0.09546          0.09350
#
#      concave points_worst  sy11etry_worst  fractal_di1ension_worst
# 414               0.06575          0.3233                  0.06165
# 507               0.09514          0.2780                  0.11680
# 397               0.08296          0.1988                  0.07053
# 311               0.05813          0.2530                  0.05695
# 548               0.03846          0.2552                  0.07920
#
# [5 rows x 32 columns]

# %%
df.shape
# Out:
# (569, 32)

# %%
df[50:55]
# Out:
#         id  diagnosis  radius_1ean  texture_1ean  peri1eter_1ean  area_1ean  \
# 50  857343          0        11.76         21.60           74.72      427.9
# 51  857373          0        13.64         16.34           87.21      571.8
# 52  857374          0        11.94         18.24           75.71      437.6
# 53  857392          1        18.22         18.70          120.30     1033.0
# 54  857438          1        15.10         22.02           97.26      712.8
#
#     s1oothness_1ean  co1pactness_1ean  concavity_1ean  concave points_1ean  \
# 50          0.08637           0.04966         0.01657              0.01115
# 51          0.07685           0.06059         0.01857              0.01723
# 52          0.08261           0.04751         0.01972              0.01349
# 53          0.11480           0.14850         0.17720              0.10600
# 54          0.09056           0.07081         0.05253              0.03334
#
#     ...  radius_worst  texture_worst  peri1eter_worst  area_worst  \
# 50  ...         12.98          25.72            82.98       516.5
# 51  ...         14.67          23.19            96.08       656.7
# 52  ...         13.10          21.33            83.67       527.2
# 53  ...         20.60          24.13           135.10      1321.0
# 54  ...         18.10          31.69           117.70      1030.0
#
#     s1oothness_worst  co1pactness_worst  concavity_worst  \
# 50            0.1085            0.08615          0.05523
# 51            0.1089            0.15820          0.10500
# 52            0.1144            0.08906          0.09203
# 53            0.1280            0.22970          0.26230
# 54            0.1389            0.20570          0.27120
#
#     concave points_worst  sy11etry_worst  fractal_di1ension_worst
# 50               0.03715          0.2433                  0.06563
# 51               0.08586          0.2346                  0.08025
# 52               0.06296          0.2785                  0.07408
# 53               0.13250          0.3021                  0.07987
# 54               0.15300          0.2675                  0.07873
#
# [5 rows x 32 columns]

# %%
df.isnull().any().any()
# Out:
# False

# %%
df.isnull().any()
# Out:
# id                         False
# diagnosis                  False
# radius_1ean                False
# texture_1ean               False
# peri1eter_1ean             False
# area_1ean                  False
# s1oothness_1ean            False
# co1pactness_1ean           False
# concavity_1ean             False
# concave points_1ean        False
# sy11etry_1ean              False
# fractal_di1ension_1ean     False
# radius_se                  False
# texture_se                 False
# peri1eter_se               False
# area_se                    False
# s1oothness_se              False
# co1pactness_se             False
# concavity_se               False
# concave points_se          False
# sy11etry_se                False
# fractal_di1ension_se       False
# radius_worst               False
# texture_worst              False
# peri1eter_worst            False
# area_worst                 False
# s1oothness_worst           False
# co1pactness_worst          False
# concavity_worst            False
# concave points_worst       False
# sy11etry_worst             False
# fractal_di1ension_worst    False
# dtype: bool

# %%
df.isnull().any().any().sum()
# Out:
# 0

# %%
import missingno as miss
miss.matrix(df)

# %%
miss.dendrogram(df)
# Out:
# C:\Users\pabitrap\Anaconda3\lib\site-packages\scipy\cluster\hierarchy.py:2833: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   ax.set_ylim([dvw, 0])

# %%
miss.bar(df)

# %%
diag_se = df['diagnosis'].value_counts()
diag_se
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %%
import seaborn as sns
sns.barplot(diag_se.index, diag_se.values)

# %%
sns.heatmap(df.corr(), square = False, mask = False)

# %%
from sklearn.model_selection import train_test_split

# %%
y = df['diagnosis']
X = df.drop(['diagnosis'], axis = 1)

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %%
X
# Out:
#            id  radius_1ean  texture_1ean  peri1eter_1ean  area_1ean  \
# 0      842302        17.99         10.38          122.80     1001.0
# 1      842517        20.57         17.77          132.90     1326.0
# 2    84300903        19.69         21.25          130.00     1203.0
# 3    84348301        11.42         20.38           77.58      386.1
# 4    84358402        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564    926424        21.56         22.39          142.00     1479.0
# 565    926682        20.13         28.25          131.20     1261.0
# 566    926954        16.60         28.08          108.30      858.1
# 567    927241        20.60         29.33          140.10     1265.0
# 568     92751         7.76         24.54           47.92      181.0
#
#      s1oothness_1ean  co1pactness_1ean  concavity_1ean  concave points_1ean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      sy11etry_1ean  ...  radius_worst  texture_worst  peri1eter_worst  \
# 0           0.2419  ...        25.380          17.33           184.60
# 1           0.1812  ...        24.990          23.41           158.80
# 2           0.2069  ...        23.570          25.53           152.50
# 3           0.2597  ...        14.910          26.50            98.87
# 4           0.1809  ...        22.540          16.67           152.20
# ..             ...  ...           ...            ...              ...
# 564         0.1726  ...        25.450          26.40           166.10
# 565         0.1752  ...        23.690          38.25           155.00
# 566         0.1590  ...        18.980          34.12           126.70
# 567         0.2397  ...        25.740          39.42           184.60
# 568         0.1587  ...         9.456          30.37            59.16
#
#      area_worst  s1oothness_worst  co1pactness_worst  concavity_worst  \
# 0        2019.0           0.16220            0.66560           0.7119
# 1        1956.0           0.12380            0.18660           0.2416
# 2        1709.0           0.14440            0.42450           0.4504
# 3         567.7           0.20980            0.86630           0.6869
# 4        1575.0           0.13740            0.20500           0.4000
# ..          ...               ...                ...              ...
# 564      2027.0           0.14100            0.21130           0.4107
# 565      1731.0           0.11660            0.19220           0.3215
# 566      1124.0           0.11390            0.30940           0.3403
# 567      1821.0           0.16500            0.86810           0.9387
# 568       268.6           0.08996            0.06444           0.0000
#
#      concave points_worst  sy11etry_worst  fractal_di1ension_worst
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 31 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 23)

# %%
def show_split_data(X_train, X_test, y_train, y_test):
    
    print(f'X train shape : {X_train.shape}')
    print(f'Y train shape : {y_train.shape}')
    print(f'X test shape  : {X_train.shape}')
    print(f'Y test shape  : {y_train.shape}')

# %%
show_split_data(X_train, X_test, y_train, y_test)
# Out:
# X train shape : (381, 31)
# Y train shape : (381,)
# X test shape  : (381, 31)
# Y test shape  : (381,)

# %%
from sklearn.metrics import confusion_matrix

# %%
import matplotlib.pyplot as plt

def show_confusion_matrix(_model_cm, title = None):
    
    f, ax = plt.subplots(figsize = (5, 5))
    
    sns.heatmap(_model_cm, annot = True, linewidth = 0, linecolor = 'red', fmt = 'g', ax = ax, cmap = 'Greens')
    
    # cmap colors:
    # YlGnBu, Blues, BuPu, Greens
    
    plt.title(title + ' Confusion Matrix')
    plt.xlabel('y Predict')
    plt.ylabel('y test')
    
    plt.show()

# %%
def get_metrics(model_cm):
    
    total = sum(sum(model_cm))
    
    accuracy = (model_cm[0, 0] + model_cm[1, 1]) / total
    accuracy = float("{:.2f}".format(accuracy))

    sensitivity = model_cm[0, 0] / (model_cm[0, 0] + model_cm[0, 1])
    sensitivity = float("{:.2f}".format(sensitivity))

    specificity = model_cm[1, 1]/(model_cm[1, 0] + model_cm[1, 1])
    specificity = float("{:.2f}".format(specificity))
    
    return accuracy, sensitivity, specificity

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB

# %%
def predict_with_model(model):
    
    model = model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    
    return y_pred, accuracy

# %%
def show_metrics(model_cm):

    total = sum(sum(model_cm))
    
    accuracy = (model_cm[0, 0] + model_cm[1, 1]) / total
    accuracy = float("{:.2f}".format(accuracy))

    sensitivity = model_cm[0, 0] / (model_cm[0, 0] + model_cm[0, 1])
    sensitivity = float("{:.2f}".format(sensitivity))

    specificity = model_cm[1, 1]/(model_cm[1, 0] + model_cm[1, 1])
    specificity = float("{:.2f}".format(specificity))
    
    print(f'accuracy : {accuracy}, sensitivity : {sensitivity}, specificity : {specificity}')

# %%
best_model_accuracy = 0
best_model = None

models = [
    MLPClassifier(),
    RandomForestClassifier(),
    KNeighborsClassifier(),
    LogisticRegression(solver = "liblinear"),
    DecisionTreeClassifier(),
    GaussianNB()
]

for model in models:
    
    model_name = model.__class__.__name__

    y_pred, accuracy = predict_with_model(model)
    
    print("-" * 30)
    print(model_name + ": " )
    
    current_model_cm = confusion_matrix(y_test, y_pred)
    show_metrics(current_model_cm)
    
    if(accuracy > best_model_accuracy):
        best_model_accuracy = accuracy
        best_model = model_name
    
    print("Accuracy: {:.2%}".format(accuracy))
    
    show_confusion_matrix(current_model_cm, model_name)
# Out:
# ------------------------------
# MLPClassifier:
# accuracy : 0.4, sensitivity : 0.0, specificity : 1.0
# Accuracy: 40.35%
# ------------------------------
# RandomForestClassifier:
# accuracy : 0.96, sensitivity : 0.97, specificity : 0.96
# Accuracy: 96.49%
# ------------------------------
# KNeighborsClassifier:
# accuracy : 0.76, sensitivity : 0.93, specificity : 0.52
# Accuracy: 76.32%
# ------------------------------
# LogisticRegression:
# accuracy : 0.4, sensitivity : 0.07, specificity : 0.89
# Accuracy: 40.35%
# ------------------------------
# DecisionTreeClassifier:
# accuracy : 0.96, sensitivity : 0.96, specificity : 0.96
# Accuracy: 95.61%
# ------------------------------
# GaussianNB:
# accuracy : 0.6, sensitivity : 0.99, specificity : 0.02
# Accuracy: 59.65%

# %%
print("Best Model : {}".format(best_model))
print("Best Model Accuracy : {:.2%}".format(best_model_accuracy))
# Out:
# Best Model : RandomForestClassifier
# Best Model Accuracy : 96.49%
